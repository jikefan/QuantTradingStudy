# %%
import pandas as pd
import numpy as np

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

folder_path = 'data'
close_price = {}
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        # 从文件名中提取基本名称（不包含扩展名）
        base_name, _ = os.path.splitext(filename)
        # 拼接完整的文件路径
        file_path = os.path.join(folder_path, filename)
        # 读取CSV文件，并将其存储在DataFrame中
        df = pd.read_csv(file_path)
        close_price[base_name] = df['close']
df = pd.DataFrame(close_price)
print(df)
# Out:
#          eth       btc    bnb    icp    ltc     SOL
# 0    1830.73  28068.26  328.5  5.765  86.75   21.96
# 1    1870.08  28669.86  321.5  5.724  88.20   22.25
# 2    1905.12  29026.16  325.9  5.939  88.88   22.24
# 3    1877.07  28838.16  323.8  5.911  88.38   21.74
# 4    1993.30  29505.61  326.5  5.943  88.61   22.82
# ..       ...       ...    ...    ...    ...     ...
# 458  3203.40  65354.02  575.1  8.887  69.59  167.37
# 459  2989.61  61498.33  542.9  8.305  65.06  152.77
# 460  2903.64  60697.99  529.6  7.760  64.65  142.52
# 461  2688.92  58161.00  496.9  7.328  62.46  138.33
# 462  2328.68  52920.00  440.6  6.829  53.53  121.57
#
# [463 rows x 6 columns]

# %%
# 计算DataFrame中所有列之间的相关性
correlation_matrix = df.corr()
print(correlation_matrix)

# 使用seaborn创建热图
plt.figure(figsize=(8, 6))  # 可以调整图形大小
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

# 添加标题
plt.title('Crypto corr matrix')

# 显示图表
plt.show()
# Out:
#           eth       btc       bnb       icp       ltc       SOL
# eth  1.000000  0.978661  0.931739  0.815526  0.266953  0.950120
# btc  0.978661  1.000000  0.935557  0.833595  0.200388  0.980345
# bnb  0.931739  0.935557  1.000000  0.734643  0.288268  0.913943
# icp  0.815526  0.833595  0.734643  1.000000  0.256554  0.861711
# ltc  0.266953  0.200388  0.288268  0.256554  1.000000  0.143707
# SOL  0.950120  0.980345  0.913943  0.861711  0.143707  1.000000
